# %%
import pandas as pd

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
col_names = index_names + setting_names + sensor_names

df = pd.read_csv("train_FD001.txt", header=None, nrows=10, names=col_names)

# %%
df
# Out:
#    unit_number  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0            0            1     2.0000     3.0000        4.0    5.00    6.00
# 1            1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 2            1            2     0.0019    -0.0003      100.0  518.67  642.15
# 3            1            3    -0.0043     0.0003      100.0  518.67  642.35
# 4            1            4     0.0007     0.0000      100.0  518.67  642.35
# 5            1            5    -0.0019    -0.0002      100.0  518.67  642.37
# 6            1            6    -0.0043    -0.0001      100.0  518.67  642.10
# 7            1            7     0.0010     0.0001      100.0  518.67  642.48
# 8            1            8    -0.0034     0.0003      100.0  518.67  642.56
# 9            1            9     0.0008     0.0001      100.0  518.67  642.12
#
#        s_3      s_4    s_5  ...    s_12     s_13     s_14     s_15   s_16  \
# ...

# %%
train_grouped_by_unit = df.groupby(by='unit_number')

# %%
max_time_cycles = train_grouped_by_unit['time_cycles'].max()

# %%
max_time_cycles
# Out:
# unit_number
# 0    1
# 1    9
# Name: time_cycles, dtype: int64

# %%
max_time_cycles.to_frame(name="max_time_cycles")
# Out:
#              max_time_cycles
# unit_number
# 0                          1
# 1                          9

# %%
df
# Out:
#    unit_number  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0            0            1     2.0000     3.0000        4.0    5.00    6.00
# 1            1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 2            1            2     0.0019    -0.0003      100.0  518.67  642.15
# 3            1            3    -0.0043     0.0003      100.0  518.67  642.35
# 4            1            4     0.0007     0.0000      100.0  518.67  642.35
# 5            1            5    -0.0019    -0.0002      100.0  518.67  642.37
# 6            1            6    -0.0043    -0.0001      100.0  518.67  642.10
# 7            1            7     0.0010     0.0001      100.0  518.67  642.48
# 8            1            8    -0.0034     0.0003      100.0  518.67  642.56
# 9            1            9     0.0008     0.0001      100.0  518.67  642.12
#
#        s_3      s_4    s_5  ...    s_12     s_13     s_14     s_15   s_16  \
# ...

# %%
merged = df.merge(max_time_cycles.to_frame(name='max_time_cycle'), left_on='unit_number',right_index=True)
merged
# Out:
#    unit_number  time_cycles  setting_1  setting_2  setting_3     s_1     s_2  \
# 0            0            1     2.0000     3.0000        4.0    5.00    6.00
# 1            1            1    -0.0007    -0.0004      100.0  518.67  641.82
# 2            1            2     0.0019    -0.0003      100.0  518.67  642.15
# 3            1            3    -0.0043     0.0003      100.0  518.67  642.35
# 4            1            4     0.0007     0.0000      100.0  518.67  642.35
# 5            1            5    -0.0019    -0.0002      100.0  518.67  642.37
# 6            1            6    -0.0043    -0.0001      100.0  518.67  642.10
# 7            1            7     0.0010     0.0001      100.0  518.67  642.48
# 8            1            8    -0.0034     0.0003      100.0  518.67  642.56
# 9            1            9     0.0008     0.0001      100.0  518.67  642.12
#
#        s_3      s_4    s_5  ...     s_13     s_14     s_15   s_16  s_17  s_18  \
# ...

# %%
import yaml, os
data = yaml.safe_load(os.path.join("test.yaml"))

# %%
data
# Out:
# 'test.yaml'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual y_test and y_pred)
y_test = np.array([10, 15, 20, 25, 30])
y_pred = np.array([12, 18, 22, 28, 32])

# Generating x-axis values for each bar
x_values = np.arange(len(y_test))

# Plotting y_test bars
plt.bar(x_values, y_test, color='blue', label='y_test')

# Plotting y_pred bars on top of y_test bars
plt.bar(x_values, y_pred, color='orange', alpha=0.5, label='y_pred')

# Adding labels and legend
plt.xlabel('Sample Index')
plt.ylabel('Values')
plt.title('Comparison of y_test and y_pred')
plt.legend()

# Show the plot
plt.show()
